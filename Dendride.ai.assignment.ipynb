# %%
import pandas as pd

# %%
df=pd.read_csv("data\iris.csv")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.shape
# Out:
# (150, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.column= pd.DataFrame(df[['sepal_length', 'sepal_width', 'petal_length','species', 'petal_width',]])
# Out:
# C:\Users\urban\AppData\Local\Temp/ipykernel_1992/2794532237.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.column= pd.DataFrame(df[['sepal_length', 'sepal_width', 'petal_length','species', 'petal_width',]])

# %%
df.column
# Out:
#      sepal_length  sepal_width  petal_length         species  petal_width
# 0             5.1          3.5           1.4     Iris-setosa          0.2
# 1             4.9          3.0           1.4     Iris-setosa          0.2
# 2             4.7          3.2           1.3     Iris-setosa          0.2
# 3             4.6          3.1           1.5     Iris-setosa          0.2
# 4             5.0          3.6           1.4     Iris-setosa          0.2
# ..            ...          ...           ...             ...          ...
# 145           6.7          3.0           5.2  Iris-virginica          2.3
# 146           6.3          2.5           5.0  Iris-virginica          1.9
# 147           6.5          3.0           5.2  Iris-virginica          2.0
# 148           6.2          3.4           5.4  Iris-virginica          2.3
# 149           5.9          3.0           5.1  Iris-virginica          1.8
#
# [150 rows x 5 columns]

# %%
 import json

  
# Opening JSON file
f = open('data/algoparams_from_ui.json')
  
# returns JSON object as 
# a dictionary
data = json.load(f)

# %%
data
# Out:
# {'session_name': 'test',
#  'session_description': 'test',
#  'design_state_data': {'session_info': {'project_id': '1',
#    'experiment_id': 'kkkk-11',
#    'dataset': 'iris_modified.csv',
#    'session_name': 'test',
#    'session_description': 'test'},
#   'target': {'prediction_type': 'Regression',
#    'target': 'petal_width',
#    'type': 'regression',
#    'partitioning': True},
#   'train': {'policy': 'Split the dataset',
#    'time_variable': 'sepal_length',
#    'sampling_method': 'No sampling(whole data)',
#    'split': 'Randomly',
#    'k_fold': False,
#    'train_ratio': 0,
#    'random_seed': 0},
#   'metrics': {'optomize_model_hyperparameters_for': 'AUC',
#    'optimize_threshold_for': 'F1 Score',
#    'compute_lift_at': 0,
#    'cost_matrix_gain_for_true_prediction_true_result': 1,
#    'cost_matrix_gain_for_true_prediction_false_result': 0,
#    'cost_matrix_gain_for_false_prediction_true_result': 0,
#    'cost_matrix_gain_for_false_prediction_false_result': 0},
# ...

# %%
for keys in data.keys():
    print(keys)
# Out:
# session_name
# session_description
# design_state_data

# %%
for values in data.values():
   print(values)
# Out:
# test
# test
# ...

# %%
X=df[["sepal_length","sepal_width","petal_length","species"]]

# %%
X
# Out:
#      sepal_length  sepal_width  petal_length         species
# 0             5.1          3.5           1.4     Iris-setosa
# 1             4.9          3.0           1.4     Iris-setosa
# 2             4.7          3.2           1.3     Iris-setosa
# 3             4.6          3.1           1.5     Iris-setosa
# 4             5.0          3.6           1.4     Iris-setosa
# ..            ...          ...           ...             ...
# 145           6.7          3.0           5.2  Iris-virginica
# 146           6.3          2.5           5.0  Iris-virginica
# 147           6.5          3.0           5.2  Iris-virginica
# 148           6.2          3.4           5.4  Iris-virginica
# 149           5.9          3.0           5.1  Iris-virginica
#
# [150 rows x 4 columns]

# %%
Y=df[["petal_width"]]

# %%
Y
# Out:
#      petal_width
# 0            0.2
# 1            0.2
# 2            0.2
# 3            0.2
# 4            0.2
# ..           ...
# 145          2.3
# 146          1.9
# 147          2.0
# 148          2.3
# 149          1.8
#
# [150 rows x 1 columns]

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
one=OneHotEncoder()

# %%
dummy=pd.get_dummies(df["species"])

# %%
dummy
# Out:
#      Iris-setosa  Iris-versicolor  Iris-virginica
# 0              1                0               0
# 1              1                0               0
# 2              1                0               0
# 3              1                0               0
# 4              1                0               0
# ..           ...              ...             ...
# 145            0                0               1
# 146            0                0               1
# 147            0                0               1
# 148            0                0               1
# 149            0                0               1
#
# [150 rows x 3 columns]

# %%
df.index.name="Id"

# %%
df.column
# Out:
#      sepal_length  sepal_width  petal_length         species  petal_width
# Id
# 0             5.1          3.5           1.4     Iris-setosa          0.2
# 1             4.9          3.0           1.4     Iris-setosa          0.2
# 2             4.7          3.2           1.3     Iris-setosa          0.2
# 3             4.6          3.1           1.5     Iris-setosa          0.2
# 4             5.0          3.6           1.4     Iris-setosa          0.2
# ..            ...          ...           ...             ...          ...
# 145           6.7          3.0           5.2  Iris-virginica          2.3
# 146           6.3          2.5           5.0  Iris-virginica          1.9
# 147           6.5          3.0           5.2  Iris-virginica          2.0
# 148           6.2          3.4           5.4  Iris-virginica          2.3
# 149           5.9          3.0           5.1  Iris-virginica          1.8
#
# [150 rows x 5 columns]

# %%
df.column=pd.merge(dummy,df.column,on="Id")

# %%
df.column.drop("species",axis=1,inplace=True)

# %%
df.column
# Out:
#      Iris-setosa  Iris-versicolor  Iris-virginica  sepal_length  sepal_width  \
# Id
# 0              1                0               0           5.1          3.5
# 1              1                0               0           4.9          3.0
# 2              1                0               0           4.7          3.2
# 3              1                0               0           4.6          3.1
# 4              1                0               0           5.0          3.6
# ..           ...              ...             ...           ...          ...
# 145            0                0               1           6.7          3.0
# 146            0                0               1           6.3          2.5
# 147            0                0               1           6.5          3.0
# 148            0                0               1           6.2          3.4
# 149            0                0               1           5.9          3.0
#
#      petal_length  petal_width
# Id
# ...

# %%
Y=df.column[["petal_width"]]

# %%
X=df.column[["Iris-setosa","Iris-versicolor","Iris-virginica","sepal_length","sepal_width","petal_length"]]

# %%
X
# Out:
#      Iris-setosa  Iris-versicolor  Iris-virginica  sepal_length  sepal_width  \
# Id
# 0              1                0               0           5.1          3.5
# 1              1                0               0           4.9          3.0
# 2              1                0               0           4.7          3.2
# 3              1                0               0           4.6          3.1
# 4              1                0               0           5.0          3.6
# ..           ...              ...             ...           ...          ...
# 145            0                0               1           6.7          3.0
# 146            0                0               1           6.3          2.5
# 147            0                0               1           6.5          3.0
# 148            0                0               1           6.2          3.4
# 149            0                0               1           5.9          3.0
#
#      petal_length
# Id
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.4, random_state=1)

# %%
# import module for linear regression model training 
from sklearn.linear_model import LinearRegression

# %%
# create an object of linearRegression class 
lr=LinearRegression()

# %%
# train the model using fit method pass training x and y 
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
lr.coef_ #slop
# Out:
# array([[-0.38223509,  0.04847848,  0.33375661, -0.14573901,  0.27800013,
#          0.3498225 ]])

# %%
lr.intercept_
# Out:
# array([-0.11356879])

# %%
Y_pred=lr.predict(X_test)
Y_pred
# Out:
# array([[0.1906974 ],
#        [0.93610857],
#        [1.34625162],
#        [0.25617524],
#        [2.36411414],
#        [1.57832011],
#        [1.86048381],
#        [0.48199042],
#        [0.2685392 ],
#        [2.09817732],
#        [1.33862609],
#        [0.39610423],
#        [2.08339399],
#        [1.4659817 ],
#        [1.44087726],
#        [0.20731415],
#        [1.21171378],
#        [1.52697288],
#        [0.18713967],
#        [0.0848885 ],
#        [1.39536448],
#        [1.55612068],
#        [1.54157122],
#        [0.20327079],
#        [2.15940237],
#        [1.31686995],
#        [0.35998362],
#        [0.34206142],
#        [1.46846785],
#        [1.74614489],
#        [1.48908563],
#        [2.06591509],
#        [1.17807932],
#        [2.02486452],
#        [1.93739668],
#        [0.28511361],
#        [1.17203544],
#        [0.18130522],
#        [1.37519   ],
#        [1.96770728],
#        [1.9871867 ],
#        [0.22367914],
#        [1.70646655],
# ...

# %%
lr.score(X_test,Y_test)
# Out:
# 0.9470492158667986

# %%
# PCA (from sklearn.decomposition import PCA)

# %%
from sklearn.decomposition import PCA

# %%
len(df.column.columns)
# Out:
# 7

# %%
df.shape
# Out:
# (150, 5)

# %%
pc = PCA(n_components=6,random_state=1)

# %%
X = df.column.drop("petal_width",axis=1)
y = df.column["petal_width"]
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=1)

# %%
X_train_pc = pc.fit_transform(X_train,y_train)
X_test_pc = pc.transform(X_test)

# %%
lin = LinearRegression()
lin.fit(X_train_pc,y_train)
# Out:
# LinearRegression()

# %%
lin.score(X_test_pc,y_test)
# Out:
# 0.9451186031886996

# %%
from sklearn.model_selection import cross_val_score

# %%
lr_cross=cross_val_score(lr,X,Y,cv=5) # total 3 fold it will create

# %%
lr_cross
# Out:
# array([0.36003685, 0.92627636, 0.59314457, 0.83853395, 0.12945751])

# %%
import numpy as np

# %%
np.mean(lr_cross)
# Out:
# 0.569489846239412
